# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('adult_tr.csv')

# %%
df.shape
# Out:
# (36631, 15)

# %%
df.head(10)
# Out:
#    age         workclass  final_weight     education  education-num  \
# 0   43           Private         34278  Some-college             10
# 1   23           Private        244698       5th-6th              3
# 2   39           Private        118286  Some-college             10
# 3   35           Private        126675       HS-grad              9
# 4   66           Private         28367     Bachelors             13
# 5   39           Private        128715       HS-grad              9
# 6   25           Private        254746     Assoc-voc             11
# 7   39  Self-emp-not-inc        167106    Assoc-acdm             12
# 8   24       Federal-gov        283918  Some-college             10
# 9   26           Private        176146       5th-6th              3
#
#        marital_status       occupation    relationship                race  \
# 0  Married-civ-spouse            Sales         Husband               White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36631 entries, 0 to 36630
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             36631 non-null  int64
#  1   workclass       36631 non-null  object
#  2   final_weight    36631 non-null  int64
#  3   education       36631 non-null  object
#  4   education-num   36631 non-null  int64
#  5   marital_status  36631 non-null  object
#  6   occupation      36631 non-null  object
#  7   relationship    36631 non-null  object
#  8   race            36631 non-null  object
#  9   sex             36631 non-null  object
#  10  capital_gain    36631 non-null  int64
#  11  capital_loss    36631 non-null  int64
#  12  hours_per_week  36631 non-null  int64
#  13  native_country  36631 non-null  object
#  14  threshold       36631 non-null  int64
# dtypes: int64(7), object(8)
# memory usage: 4.2+ MB

# %%
pd.isnull(df)
# Out:
#          age  workclass  final_weight  education  education-num  \
# 0      False      False         False      False          False
# 1      False      False         False      False          False
# 2      False      False         False      False          False
# 3      False      False         False      False          False
# 4      False      False         False      False          False
# ...      ...        ...           ...        ...            ...
# 36626  False      False         False      False          False
# 36627  False      False         False      False          False
# 36628  False      False         False      False          False
# 36629  False      False         False      False          False
# 36630  False      False         False      False          False
#
#        marital_status  occupation  relationship   race    sex  capital_gain  \
# 0               False       False         False  False  False         False
# ...

# %%
pd.isnull(df).sum()
# Out:
# age               0
# workclass         0
# final_weight      0
# education         0
# education-num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# threshold         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'final_weight', 'education', 'education-num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'threshold'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 age  final_weight  education-num  capital_gain  capital_loss  \
# count  36631.000000  3.663100e+04   36631.000000  36631.000000  36631.000000
# mean      38.663946  1.898852e+05      10.079004   1091.783244     85.905108
# std       13.731151  1.058737e+05       2.565630   7524.390241    399.974900
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.177890e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.782820e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.373190e+05      12.000000      0.000000      0.000000
# max       90.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week     threshold
# count    36631.000000  36631.000000
# mean        40.424449      0.239278
# std         12.394869      0.426649
# min          1.000000      0.000000
# 25%         40.000000      0.000000
# 50%         40.000000      0.000000
# ...

# %%
df[['age', 'capital_gain', 'capital_loss']].describe()
# Out:
#                 age  capital_gain  capital_loss
# count  36631.000000  36631.000000  36631.000000
# mean      38.663946   1091.783244     85.905108
# std       13.731151   7524.390241    399.974900
# min       17.000000      0.000000      0.000000
# 25%       28.000000      0.000000      0.000000
# 50%       37.000000      0.000000      0.000000
# 75%       48.000000      0.000000      0.000000
# max       90.000000  99999.000000   4356.000000

# %%
ax = sns.countplot(x = 'race', data=df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)

# %%
pip install shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import shap

# %%
def box_graph_bivar(colx,coly):
    plt.figure(figsize=(10,10))
    sns.boxplot(data=df,x=colx,y=coly,palette='cubehelix')
    plt.xticks(rotation=90)
    plt.show()

# %%
box_graph_bivar('age','workclass')

# %%
box_graph_bivar('age','marital_status')

# %%
plt.rcParams['figure.figsize'] = (15, 3)
plt.subplot(1,3,1)
sns.distplot(df['capital_gain'])
plt.subplot(1,3,2)
sns.distplot(df['capital_loss'])
plt.show()
# Out:
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
import pandas as pd
df = pd.read_csv('adult_tr.csv')
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15, 3)
plt.subplot(1,3,1)
sns.barplot(x = df['workclass'],y = df['capital_gain'])
plt.subplot(1,3,2)
sns.barplot(x = df['workclass'],y = df['capital_loss'])
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 3)
plt.subplot(1,3,1)
sns.barplot(x = df['capital_gain'],y = df['occupation'])
plt.subplot(1,3,2)
sns.barplot(x = df['capital_loss'],y = df['occupation'])
plt.show()

# %%
sns.scatterplot(x=df['capital_gain'], y = df['capital_loss'], hue = df['sex'])
# Out:
# <Axes: xlabel='capital_gain', ylabel='capital_loss'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
df = pd.read_csv ('adult_tr.csv')
# Assuming data is loaded into a DataFrame called df
X = df[['age', 'final_weight', 'education-num', 'capital_gain']]
Y = df['hours_per_week']

# Splitting the data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=1)

# Creating and fitting the linear regression model
model = LinearRegression()
model.fit(X_train, Y_train)

# Predicting on the test set
Y_pred = model.predict(X_test)

# Calculating RMSE
rmse = np.sqrt(mean_squared_error(Y_test, Y_pred))
print("RMSE of the baseline model:", rmse)
# Out:
# RMSE of the baseline model: 12.019784046398748
